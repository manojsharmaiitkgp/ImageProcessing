# %%
# color conversion

# %%
from skimage import io

# %%
img=io.imread('ch_0/lena.png')

# %%
io.imshow(img)

# %%
fn='ch_0/img_save.png'
io.imsave(fn,img)

# %%
from skimage import data
img_cam=data.camera()
io.imshow(img_cam)

# %%
fn='ch_0/camera.png'
io.imsave(fn,img_cam)

# %%
img2=data.text()
io.imshow(img2)

# %%
img3=data.coffee()
io.imshow(img3)

# %%
from skimage import io, color,data
im4= data.coffee()
img_gray=color.rgb2gray(im4)
io.imshow(img_gray)

# %%
im4=data.astronaut()
img_hsv=color.rgb2hsv(im4)
io.imshow(im4)

# %%
io.imshow(img_hsv)
