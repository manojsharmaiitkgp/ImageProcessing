# %%
from PIL import Image
from PIL import ImageFilter
import matplotlib.pyplot as plt

# %%
fn='ch_02/images/image.jpg'
img=Image.open(fn)

# %%
def myDisplay(x,y):
    plt.subplot(1,2,1),plt.imshow(x)
    plt.subplot(1,2,2),plt.imshow(y)

# %%
ft=ImageFilter.GaussianBlur(2)
b_img=img.filter(ft)

plt.figure(figsize=(12,12))
myDisplay(img,b_img)

# %%
from skimage import io
from skimage import filters

# %%
im=io.imread(fn)

# %%
plt.figure(figsize=(8,8))
out=filters.gaussian(im,sigma=5)
io.imshow(out)
# Out:
# <ipython-input-15-e42381e999e4>:2: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.
#   out=filters.gaussian(im,sigma=5)

# %%
plt.subplot(1,2,1)
plt.imshow(out)

# %%
# Summary io.imshow is having issue with subplot

# %%
plt.figure(figsize=(12,12))
out=filters.gaussian(im,sigma=15)
myDisplay(im,out)
# Out:
# <ipython-input-20-8bd349d5a9ba>:2: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.
#   out=filters.gaussian(im,sigma=15)

# %%
# Median filter

# %%
from PIL import Image
from PIL import ImageFilter

# %%
img=Image.open(fn)

# %%
mf=ImageFilter.MedianFilter(7)
# median filter is working in PIL, valid for color image
b_img=img.filter(mf)

# %%
plt.figure(figsize=(12,12))
myDisplay(img,b_img)

# %%
from skimage import io
from skimage import filters
from skimage.morphology import disk
import numpy as np

# %%
img=io.imread(fn)

img=img[:,:,0]

print('type(img)=',type(img))
print(img.shape)

from skimage.filters import median

med = median(img, disk(7))
myDisplay(img,med)
# Out:
# type(img)= <class 'numpy.ndarray'>
# (512, 512)

# %%
from skimage import data
from skimage.morphology import disk
from skimage.filters import median
img = data.camera()
print('img=',img)
print('type(img)=',type(img))
med = median(img, disk(7))
# Out:
# img= [[156 157 160 ... 152 152 152]
#  [156 157 159 ... 152 152 152]
#  [158 157 156 ... 152 152 152]
#  ...
#  [121 123 126 ... 121 113 111]
#  [121 123 126 ... 121 113 111]
#  [121 123 126 ... 121 113 111]]
# type(img)= <class 'numpy.ndarray'>

# %%
myDisplay(img,med)

# %%
# Summary skimage io and its corresponding median filter
#  is working only on single channel image
